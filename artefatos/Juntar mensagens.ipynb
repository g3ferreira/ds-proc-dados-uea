# %% [markdown]
# ## Notebook utilizado para juntar os arquivos que possuem as traduções do campo reviewbody e incluir os comentários em inglês no dataset principal

# %% [markdown]
# ### Importando os pacotes

# %%
import pandas as pd

# %% [markdown]
# ### Lendo os arquivos que possuem as traduções do campo reviewBody

# %%
df_reviewBody_0 = pd.read_csv('/content/drive/MyDrive/UEA - Pós Ciência de Dados/2. Programação para Ciência de Dados/ds-proc-dados-uea/artefatos/dados/partes reviewBodyEn/reviewBodyEn - 0 a 19.999.csv', index_col=0)

# %%
df_reviewBody_1 = pd.read_csv('/content/drive/MyDrive/UEA - Pós Ciência de Dados/2. Programação para Ciência de Dados/ds-proc-dados-uea/artefatos/dados/partes reviewBodyEn/reviewBodyEn - 20.000 a 39.999.csv', index_col=0)

# %%
df_reviewBody_2 = pd.read_csv('/content/drive/MyDrive/UEA - Pós Ciência de Dados/2. Programação para Ciência de Dados/ds-proc-dados-uea/artefatos/dados/partes reviewBodyEn/reviewBodyEn - 40.000 a 69.999.csv', index_col=0)

# %%
df_reviewBody_3 = pd.read_csv('/content/drive/MyDrive/UEA - Pós Ciência de Dados/2. Programação para Ciência de Dados/ds-proc-dados-uea/artefatos/dados/partes reviewBodyEn/reviewBodyEn - 70.000 a 99.999.csv', index_col=0)

# %% [markdown]
# ### Lendo o dataset do professor

# %%
df_dataset = pd.read_json('http://tiagodemelo.info/datasets/dataset-v2.dat', lines=True)

# %% [markdown]
# ### Juntando os dataframes com as traduções dos comentários

# %%
df_reviewBody = pd.concat([df_reviewBody_0, df_reviewBody_1, df_reviewBody_2, df_reviewBody_3])

# %%
df_reviewBody
# Out:
#                                               reviewBody
# 0      Wonderful food, place for real shrimp gum.\nTh...
# 1      Good food, nice drinks and a very cozy atmosph...
# 2      Excellent to go with the family! Great food, p...
# 3      I have had ice cream at Visabor for over 30 ye...
# 4      The best hamburger I've ever eaten! Excellent ...
# ...                                                  ...
# 99995  Not yet officially opened, it is serving in so...
# 99996  Good service, beautiful place, very tasty food...
# 99997  Rio Scenarium is one of the most famous clubs ...
# 99998  I went by indication and with good expectation...
# 99999  Fantastic experience with delicious food and e...
#
# [100000 rows x 1 columns]

# %% [markdown]
# ### Incluindo os comentários inglês no dataset principal

# %%
df_dataset['reviewBodyEn'] = df_reviewBody

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   title            100000 non-null  object
#  1   reviewId         100000 non-null  int64
#  2   restaurantId     99999 non-null   float64
#  3   author           99999 non-null   object
#  4   reviewBody       99999 non-null   object
#  5   language         100000 non-null  object
#  6   mobileDevice     100000 non-null  object
#  7   userLocation     100000 non-null  object
#  8   publicationDate  100000 non-null  object
#  9   visitDate        100000 non-null  object
#  10  ratingValue      100000 non-null  int64
#  11  itemReviewed     100000 non-null  object
#  12  reviewBodyEn     99999 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 9.9+ MB

# %% [markdown]
# ### Salvando todos os comentários inglês em um único arquivo

# %%
df_reviewBody.to_csv('/content/drive/MyDrive/UEA - Pós Ciência de Dados/2. Programação para Ciência de Dados/ds-proc-dados-uea/artefatos/dados/reviewBodyEn.csv')

# %% [markdown]
# ### Salvando o dataset principal já com os comentários inglês incluídos

# %%
df_dataset.to_csv('/content/drive/MyDrive/UEA - Pós Ciência de Dados/2. Programação para Ciência de Dados/ds-proc-dados-uea/artefatos/dados/dataset.csv')
